# %%
# !pip install sqlalchemy mysql-python mysqlclient pymysql mysql-connector-python python-dotenv
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.0.25)
# Collecting mysql-python
#   Using cached MySQL-python-1.2.5.zip (108 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: mysqlclient in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.2.1)
# Requirement already satisfied: pymysql in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.1.0)
# Collecting mysql-connector-python
#   Using cached mysql_connector_python-8.3.0-cp310-cp310-win_amd64.whl.metadata (2.0 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (3.0.3)
# Using cached mysql_connector_python-8.3.0-cp310-cp310-win_amd64.whl (15.4 MB)
# Building wheels for collected packages: mysql-python
#   Building wheel for mysql-python (pyproject.toml): started
#   Building wheel for mysql-python (pyproject.toml): finished with status 'error'
# Failed to build mysql-python
#   error: subprocess-exited-with-error
#
#   Building wheel for mysql-python (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [54 lines of output]
#   C:\Users\user\AppData\Local\Temp\pip-build-env-mmycnmvs\overlay\Lib\site-packages\setuptools\dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'distribution-name' will not be supported in future
#           versions. Please use the underscore name 'distribution_name' instead.
#
#           By 2024-Sep-26, you need to update your project and remove deprecated calls
#           or your builds will no longer be supported.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   C:\Users\user\AppData\Local\Temp\pip-build-env-mmycnmvs\overlay\Lib\site-packages\setuptools\dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'build-requires' will not be supported in future
#           versions. Please use the underscore name 'build_requires' instead.
#
#           By 2024-Sep-26, you need to update your project and remove deprecated calls
#           or your builds will no longer be supported.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
#   copying _mysql_exceptions.py -> build\lib.win-amd64-cpython-310
#   creating build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\__init__.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\converters.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\connections.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\cursors.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\release.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\times.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   creating build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\__init__.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\CR.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\FIELD_TYPE.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\ER.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\FLAG.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\REFRESH.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\CLIENT.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   running build_ext
#   building '_mysql' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mysql-python
# ERROR: Could not build wheels for mysql-python, which is required to install pyproject.toml-based projects

# %%
# !pip install sqlalchemy mysql-python mysqlclient pymysql mysql-connector-python python-dotenv
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.0.25)
# Collecting mysql-python
#   Using cached MySQL-python-1.2.5.zip (108 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: mysqlclient in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.2.1)
# Requirement already satisfied: pymysql in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.1.0)
# Collecting mysql-connector-python
#   Using cached mysql_connector_python-8.3.0-cp310-cp310-win_amd64.whl.metadata (2.0 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (3.0.3)
# Using cached mysql_connector_python-8.3.0-cp310-cp310-win_amd64.whl (15.4 MB)
# Building wheels for collected packages: mysql-python
#   Building wheel for mysql-python (pyproject.toml): started
#   Building wheel for mysql-python (pyproject.toml): finished with status 'error'
# Failed to build mysql-python
#   error: subprocess-exited-with-error
#
#   Building wheel for mysql-python (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [54 lines of output]
#   C:\Users\user\AppData\Local\Temp\pip-build-env-ntca3p68\overlay\Lib\site-packages\setuptools\dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'distribution-name' will not be supported in future
#           versions. Please use the underscore name 'distribution_name' instead.
#
#           By 2024-Sep-26, you need to update your project and remove deprecated calls
#           or your builds will no longer be supported.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   C:\Users\user\AppData\Local\Temp\pip-build-env-ntca3p68\overlay\Lib\site-packages\setuptools\dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'build-requires' will not be supported in future
#           versions. Please use the underscore name 'build_requires' instead.
#
#           By 2024-Sep-26, you need to update your project and remove deprecated calls
#           or your builds will no longer be supported.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
#   copying _mysql_exceptions.py -> build\lib.win-amd64-cpython-310
#   creating build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\__init__.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\converters.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\connections.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\cursors.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\release.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\times.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   creating build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\__init__.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\CR.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\FIELD_TYPE.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\ER.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\FLAG.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\REFRESH.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\CLIENT.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   running build_ext
#   building '_mysql' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mysql-python
# ERROR: Could not build wheels for mysql-python, which is required to install pyproject.toml-based projects

# %%
# !pip install sqlalchemy mysql-python mysqlclient pymysql mysql-connector-python python-dotenv
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.0.25)
# Collecting mysql-python
#   Using cached MySQL-python-1.2.5.zip (108 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: mysqlclient in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.2.1)
# Requirement already satisfied: pymysql in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.1.0)
# Collecting mysql-connector-python
#   Using cached mysql_connector_python-8.3.0-cp310-cp310-win_amd64.whl.metadata (2.0 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (3.0.3)
# Using cached mysql_connector_python-8.3.0-cp310-cp310-win_amd64.whl (15.4 MB)
# Building wheels for collected packages: mysql-python
#   Building wheel for mysql-python (pyproject.toml): started
#   Building wheel for mysql-python (pyproject.toml): finished with status 'error'
# Failed to build mysql-python
#   error: subprocess-exited-with-error
#
#   Building wheel for mysql-python (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [54 lines of output]
#   C:\Users\user\AppData\Local\Temp\pip-build-env-wmgw603o\overlay\Lib\site-packages\setuptools\dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'distribution-name' will not be supported in future
#           versions. Please use the underscore name 'distribution_name' instead.
#
#           By 2024-Sep-26, you need to update your project and remove deprecated calls
#           or your builds will no longer be supported.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   C:\Users\user\AppData\Local\Temp\pip-build-env-wmgw603o\overlay\Lib\site-packages\setuptools\dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'build-requires' will not be supported in future
#           versions. Please use the underscore name 'build_requires' instead.
#
#           By 2024-Sep-26, you need to update your project and remove deprecated calls
#           or your builds will no longer be supported.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
#   copying _mysql_exceptions.py -> build\lib.win-amd64-cpython-310
#   creating build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\__init__.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\converters.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\connections.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\cursors.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\release.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\times.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   creating build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\__init__.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\CR.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\FIELD_TYPE.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\ER.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\FLAG.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\REFRESH.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\CLIENT.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   running build_ext
#   building '_mysql' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mysql-python
# ERROR: Could not build wheels for mysql-python, which is required to install pyproject.toml-based projects

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.0.25)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (3.0.3)

# %%
pip install mysql
# Out:
# Requirement already satisfied: mysql in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.0.3)
# Requirement already satisfied: mysqlclient in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mysql) (2.2.1)

# %%
pip install sqlalchemy mysql-python mysqlclient pymysql mysql-connector-python python-dotenv
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.0.25)
# Collecting mysql-python
#   Using cached MySQL-python-1.2.5.zip (108 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: mysqlclient in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (2.2.1)
# Requirement already satisfied: pymysql in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.1.0)
# Collecting mysql-connector-python
#   Using cached mysql_connector_python-8.3.0-cp310-cp310-win_amd64.whl.metadata (2.0 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (3.0.3)
# Using cached mysql_connector_python-8.3.0-cp310-cp310-win_amd64.whl (15.4 MB)
# Building wheels for collected packages: mysql-python
#   Building wheel for mysql-python (pyproject.toml): started
#   Building wheel for mysql-python (pyproject.toml): finished with status 'error'
# Failed to build mysql-python
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Building wheel for mysql-python (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [54 lines of output]
#   C:\Users\user\AppData\Local\Temp\pip-build-env-3cp60x4j\overlay\Lib\site-packages\setuptools\dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'distribution-name' will not be supported in future
#           versions. Please use the underscore name 'distribution_name' instead.
#
#           By 2024-Sep-26, you need to update your project and remove deprecated calls
#           or your builds will no longer be supported.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   C:\Users\user\AppData\Local\Temp\pip-build-env-3cp60x4j\overlay\Lib\site-packages\setuptools\dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'build-requires' will not be supported in future
#           versions. Please use the underscore name 'build_requires' instead.
#
#           By 2024-Sep-26, you need to update your project and remove deprecated calls
#           or your builds will no longer be supported.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     opt = self.warn_dash_deprecation(opt, section)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-310
#   copying _mysql_exceptions.py -> build\lib.win-amd64-cpython-310
#   creating build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\__init__.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\converters.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\connections.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\cursors.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\release.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   copying MySQLdb\times.py -> build\lib.win-amd64-cpython-310\MySQLdb
#   creating build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\__init__.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\CR.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\FIELD_TYPE.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\ER.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\FLAG.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\REFRESH.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   copying MySQLdb\constants\CLIENT.py -> build\lib.win-amd64-cpython-310\MySQLdb\constants
#   running build_ext
#   building '_mysql' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mysql-python
# ERROR: Could not build wheels for mysql-python, which is required to install pyproject.toml-based projects

# %%
# 1.5 Workaround for mysqldb
# import pymysql
# pymysql.install_as_MySQLdb()
import MySQLdb

# %%
# 2. Accessing the database
# from dotenv import load_dotenv

# import os

# %%
# load_dotenv()
load_dotenv('env_var.txt')

# HOST_AND_PORT = '20.218.241.192:3306'
# DB_NAME = 'sakila'
# USERNAME = 'dapLearner'
# PASSWORD = '$qlQu3ry&B!gData'

# print(DB_NAME)

# %%
# !pip install sqlalchemy
# !pip install MySQLdb
import sqlalchemy as sa
# Import pandas
import pandas as pd
# Create the DB engine connector
db_cnx = sa.create_engine(f'mysql://{USERNAME}:{PASSWORD}@{HOST_AND_PORT}/{DB_NAME}')
# Read the Customer Table
db_query = '''
        SELECT *
        FROM customer
        '''
cust_df = pd.read_sql(db_query, db_cnx)
cust_df.head()
